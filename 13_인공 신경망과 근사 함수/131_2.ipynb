# %% [markdown]
# # 인공 신경망과 근사 함수

# %% [markdown]
# ## 2차 함수 근사해 보기

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
NUM_SAMPLES = 1000

np.random.seed(int(time.time()))

# %%
xs= np.random.uniform(-2, 0.5, NUM_SAMPLES)
np.random.shuffle(xs)
print(xs[:5])
# Out:
# [-1.38514143 -0.6544155   0.36568964 -0.25730793  0.20617157]

# %%
ys = 2*xs**2 + 3*xs + 5
print(ys[:5])
# Out:
# [4.68180928 3.89327279 6.36452677 4.36049096 5.70352813]

# %%
plt.plot(xs, ys, 'b.')
plt.show()

# %% [markdown]
# ## 실제 데이터 생성하기

# %%
ys += 0.1*np.random.randn(NUM_SAMPLES)

plt.plot(xs, ys, 'g.')
plt.show()
