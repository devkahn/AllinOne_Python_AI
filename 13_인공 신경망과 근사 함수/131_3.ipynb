# %% [markdown]
# # 인공 신경망과 근사 함수

# %% [markdown]
# ## 2차 함수 근사해 보기

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
NUM_SAMPLES = 10000

np.random.seed(int(time.time()))

# %%
xs= np.random.uniform(-2, 0.5, NUM_SAMPLES)
np.random.shuffle(xs)
print(xs[:5])
# Out:
# [ 0.09320404 -0.66667602 -0.01016021 -1.01522636 -0.54200798]

# %%
ys = 2*xs**2 + 3*xs + 5
print(ys[:5])
# Out:
# [5.2969861  3.88888577 4.96972583 4.01569004 3.96152136]

# %%
plt.plot(xs, ys, 'b.')
plt.show()

# %% [markdown]
# ## 실제 데이터 생성하기

# %%
ys += 0.1*np.random.randn(NUM_SAMPLES)

plt.plot(xs, ys, 'g.')
plt.show()

# %% [markdown]
# ## 훈련, 실험 데이터 분리하기

# %%
NUM_SPLIT =int(0.8*NUM_SAMPLES)

x_train, x_test = np.split(xs, [NUM_SPLIT])
y_train, y_test = np.split(ys, [NUM_SPLIT])

# %%
plt.plot(x_train, y_train, 'b.', label = 'train')
plt.plot(x_test, y_test, 'r.', label = 'test')
plt.legend()
plt.show()
