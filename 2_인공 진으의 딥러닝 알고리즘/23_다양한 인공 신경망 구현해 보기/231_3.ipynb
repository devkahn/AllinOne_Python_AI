# %% [markdown]
# # 다양한 인공 신경망 구현해 보기

# %% [markdown]
# ## 3입력 3출력 인공 신경망 구현하기

# %%
x1, x2, x3 = 2, 3, 4
t1, t2, t3 = 27, -30, 179
w1, w4, w7 = 3, 5, 8
w2, w5, w8 = 4, 6, 9
w3, w6, w9 = 5, 7, 10
b1, b2, b3 = 1, 2, 3

for epoch in range(2000):
    print('epoch: %d' %epoch)
    
    y1 = x1*w1 + x2*w2 + x3*w3 + b1
    y2 = x1*w4 + x2*w5 + x3*w6 + b2
    y3 = x1*w7 + x2*w8 + x3*w9 + b3
    print('y1, y2, y3 = %6.3f, %6.3f, %6.3f' %(y1, y2, y3))
    
    E = (y1-t1)**2/2 + (y2-t2)**2/2 + (y3-t3)**2/2
    print('E  = %.7f' %E)
    if E < 0.0000001:
        break
    
    y1b, y2b, y3b = y1 - t1, y2 - t2, y3 - t3
    x1b = y1b*w1 + y2b*w4 + y3b*w7
    x2b = y1b*w2 + y2b*w5 + y3b*w8
    x3b = y1b*w3 + y2b*w6 + y3b*w9
    
    w1b, w4b, w7b = x1*y1b, x1*y2b, x1*y3b
    w2b, w5b, w8b = x2*y1b, x2*y2b, x2*y3b
    w3b, w6b, w9b = x3*y1b, x3*y2b, x3*y3b
    b1b, b2b, b3b = 1*y1b, 1*y2b, 2*y3b
    print( 'x1b, x2b,x3b  = %6.3f, %6.3f, %6.3f' %(x1b, x2b, x3b))
    print( 'w1b, x4b,x7b  = %6.3f, %6.3f, %6.3f' %(w1b, w4b, w7b))
    print( 'w2b, x5b,x8b  = %6.3f, %6.3f, %6.3f' %(w2b, w5b, w8b))
    print( 'w3b, x6b,x9b  = %6.3f, %6.3f, %6.3f' %(w3b, w6b, w9b))
    print( 'b1b, b2b,b3b  = %6.3f, %6.3f, %6.3f' %(b1b, b2b, b3b))
    
    lr = 0.01
    w1, w4, w7 = w1 - lr*w1b, w4 - lr*w4b, w7 - lr*w7b
    w2, w5, w8 = w2 - lr*w2b, w5 - lr*w5b, w8 - lr*w8b
    w3, w6, w9 = w3 - lr*w3b, w6 - lr*w6b, w9 - lr*w9b
    b1, b2, b3 = b1 - lr*b1b, b2 - lr*b2b, b3 - lr*b3b
    
    print('w1, w4, w7  = %6.3f, %6.3f, %6.3f' %(w1, w4, w7))
    print('w2, w5, w8  = %6.3f, %6.3f, %6.3f' %(w2, w5, w8))
    print('w3, w6, w9  = %6.3f, %6.3f, %6.3f' %(w3, w6, w9))
# Out:
# epoch: 0
# y1, y2, y3 = 39.000, 58.000, 86.000
# E  = 8268.5000000
# x1b, x2b,x3b  = -268.000, -261.000, -254.000
# w1b, x4b,x7b  = 24.000, 176.000, -186.000
# w2b, x5b,x8b  = 36.000, 264.000, -279.000
# w3b, x6b,x9b  = 48.000, 352.000, -372.000
# b1b, b2b,b3b  = 12.000, 88.000, -186.000
# w1, w4, w7  =  2.760,  3.240,  9.860
# w2, w5, w8  =  3.640,  3.360, 11.790
# w3, w6, w9  =  4.520,  3.480, 13.720
# epoch: 1
# y1, y2, y3 = 35.400, 31.600, 114.830
# E  = 3991.4544500
# x1b, x2b,x3b  = -409.948, -519.012, -628.076
# w1b, x4b,x7b  = 16.800, 123.200, -128.340
# w2b, x5b,x8b  = 25.200, 184.800, -192.510
# w3b, x6b,x9b  = 33.600, 246.400, -256.680
# b1b, b2b,b3b  =  8.400, 61.600, -128.340
# w1, w4, w7  =  2.592,  2.008, 11.143
# w2, w5, w8  =  3.388,  1.512, 13.715
# w3, w6, w9  =  4.184,  1.016, 16.287
# epoch: 2
# y1, y2, y3 = 32.880, 13.120, 134.723
# E  = 1927.1940476
# x1b, x2b,x3b  = -391.574, -522.149, -652.724
# w1b, x4b,x7b  = 11.760, 86.240, -88.555
# w2b, x5b,x8b  = 17.640, 129.360, -132.832
# w3b, x6b,x9b  = 23.520, 172.480, -177.109
# b1b, b2b,b3b  =  5.880, 43.120, -88.555
# w1, w4, w7  =  2.474,  1.146, 12.029
# w2, w5, w8  =  3.212,  0.218, 15.043
# w3, w6, w9  =  3.949, -0.709, 18.058
# epoch: 3
# y1, y2, y3 = 31.116,  0.184, 148.449
# E  = 930.6997522
# x1b, x2b,x3b  = -322.737, -439.785, -556.834
# w1b, x4b,x7b  =  8.232, 60.368, -61.103
# w2b, x5b,x8b  = 12.348, 90.552, -91.654
# w3b, x6b,x9b  = 16.464, 120.736, -122.205
# b1b, b2b,b3b  =  4.116, 30.184, -61.103
# w1, w4, w7  =  2.392,  0.542, 12.640
# w2, w5, w8  =  3.088, -0.687, 15.960
# w3, w6, w9  =  3.784, -1.916, 19.280
# epoch: 4
# y1, y2, y3 = 29.881, -8.871, 157.920
# E  = 449.5558585
# x1b, x2b,x3b  = -248.114, -342.063, -436.013
# w1b, x4b,x7b  =  5.762, 42.258, -42.161
# w2b, x5b,x8b  =  8.644, 63.386, -63.241
# w3b, x6b,x9b  = 11.525, 84.515, -84.322
# b1b, b2b,b3b  =  2.881, 21.129, -42.161
# w1, w4, w7  =  2.334,  0.119, 13.062
# w2, w5, w8  =  3.002, -1.321, 16.592
# w3, w6, w9  =  3.669, -2.761, 20.123
# epoch: 5
# y1, y2, y3 = 29.017, -15.210, 164.455
# E  = 217.1939004
# x1b, x2b,x3b  = -183.514, -254.828, -326.142
# w1b, x4b,x7b  =  4.034, 29.580, -29.091
# w2b, x5b,x8b  =  6.051, 44.370, -43.636
# w3b, x6b,x9b  =  8.067, 59.161, -58.182
# b1b, b2b,b3b  =  2.017, 14.790, -29.091
# w1, w4, w7  =  2.294, -0.176, 13.352
# w2, w5, w8  =  2.941, -1.765, 17.029
# w3, w6, w9  =  3.588, -3.353, 20.705
# epoch: 6
# y1, y2, y3 = 28.412, -19.647, 168.964
# E  = 104.9545905
# x1b, x2b,x3b  = -132.599, -185.025, -237.451
# w1b, x4b,x7b  =  2.824, 20.706, -20.073
# w2b, x5b,x8b  =  4.235, 31.059, -30.109
# w3b, x6b,x9b  =  5.647, 41.412, -40.146
# b1b, b2b,b3b  =  1.412, 10.353, -20.073
# w1, w4, w7  =  2.266, -0.384, 13.553
# w2, w5, w8  =  2.899, -2.075, 17.330
# w3, w6, w9  =  3.532, -3.767, 21.106
# epoch: 7
# y1, y2, y3 = 27.988, -22.753, 172.075
# E  = 50.7276820
# x1b, x2b,x3b  = -94.398, -132.186, -169.975
# w1b, x4b,x7b  =  1.977, 14.494, -13.850
# w2b, x5b,x8b  =  2.965, 21.742, -20.775
# w3b, x6b,x9b  =  3.953, 28.989, -27.700
# b1b, b2b,b3b  =  0.988,  7.247, -13.850
# w1, w4, w7  =  2.246, -0.528, 13.692
# w2, w5, w8  =  2.869, -2.293, 17.538
# w3, w6, w9  =  3.492, -4.057, 21.383
# epoch: 8
# y1, y2, y3 = 27.692, -24.927, 174.222
# E  = 24.5232622
# x1b, x2b,x3b  = -66.551, -93.446, -120.342
# w1b, x4b,x7b  =  1.384, 10.146, -9.557
# w2b, x5b,x8b  =  2.075, 15.219, -14.335
# w3b, x6b,x9b  =  2.767, 20.292, -19.113
# b1b, b2b,b3b  =  0.692,  5.073, -9.557
# w1, w4, w7  =  2.232, -0.630, 13.787
# w2, w5, w8  =  2.848, -2.445, 17.681
# w3, w6, w9  =  3.465, -4.260, 21.575
# epoch: 9
# y1, y2, y3 = 27.484, -26.449, 175.703
# E  = 11.8577134
# x1b, x2b,x3b  = -46.613, -65.598, -84.582
# w1b, x4b,x7b  =  0.968,  7.102, -6.594
# w2b, x5b,x8b  =  1.453, 10.653, -9.891
# w3b, x6b,x9b  =  1.937, 14.204, -13.188
# b1b, b2b,b3b  =  0.484,  3.551, -6.594
# w1, w4, w7  =  2.223, -0.701, 13.853
# w2, w5, w8  =  2.834, -2.551, 17.780
# w3, w6, w9  =  3.445, -4.402, 21.706
# epoch: 10
# y1, y2, y3 = 27.339, -27.514, 176.725
# E  = 5.7347296
# x1b, x2b,x3b  = -32.505, -45.830, -59.156
# w1b, x4b,x7b  =  0.678,  4.972, -4.550
# w2b, x5b,x8b  =  1.017,  7.457, -6.825
# w3b, x6b,x9b  =  1.356,  9.943, -9.100
# b1b, b2b,b3b  =  0.339,  2.486, -4.550
# w1, w4, w7  =  2.216, -0.751, 13.899
# w2, w5, w8  =  2.824, -2.626, 17.848
# w3, w6, w9  =  3.432, -4.501, 21.797
# epoch: 11
# y1, y2, y3 = 27.237, -28.260, 177.430
# E  = 2.7740481
# x1b, x2b,x3b  = -22.598, -31.916, -41.234
# w1b, x4b,x7b  =  0.475,  3.480, -3.139
# w2b, x5b,x8b  =  0.712,  5.220, -4.709
# w3b, x6b,x9b  =  0.949,  6.960, -6.279
# b1b, b2b,b3b  =  0.237,  1.740, -3.139
# w1, w4, w7  =  2.211, -0.785, 13.930
# w2, w5, w8  =  2.817, -2.678, 17.895
# w3, w6, w9  =  3.422, -4.571, 21.860
# epoch: 12
# y1, y2, y3 = 27.166, -28.782, 177.917
# E  = 1.3421586
# x1b, x2b,x3b  = -15.677, -22.177, -28.676
# w1b, x4b,x7b  =  0.332,  2.436, -2.166
# w2b, x5b,x8b  =  0.498,  3.654, -3.249
# w3b, x6b,x9b  =  0.664,  4.872, -4.332
# b1b, b2b,b3b  =  0.166,  1.218, -2.166
# w1, w4, w7  =  2.208, -0.810, 13.952
# w2, w5, w8  =  2.812, -2.715, 17.928
# w3, w6, w9  =  3.416, -4.620, 21.904
# epoch: 13
# y1, y2, y3 = 27.116, -29.147, 178.253
# E  = 0.6495045
# x1b, x2b,x3b  = -10.861, -15.386, -19.911
# w1b, x4b,x7b  =  0.233,  1.705, -1.495
# w2b, x5b,x8b  =  0.349,  2.558, -2.242
# w3b, x6b,x9b  =  0.465,  3.410, -2.989
# b1b, b2b,b3b  =  0.116,  0.853, -1.495
# w1, w4, w7  =  2.205, -0.827, 13.967
# w2, w5, w8  =  2.808, -2.740, 17.950
# w3, w6, w9  =  3.411, -4.654, 21.933
# epoch: 14
# y1, y2, y3 = 27.081, -29.403, 178.484
# E  = 0.3143755
# x1b, x2b,x3b  = -7.516, -10.663, -13.810
# w1b, x4b,x7b  =  0.163,  1.194, -1.031
# w2b, x5b,x8b  =  0.244,  1.791, -1.547
# w3b, x6b,x9b  =  0.326,  2.387, -2.063
# b1b, b2b,b3b  =  0.081,  0.597, -1.031
# w1, w4, w7  =  2.204, -0.839, 13.977
# w2, w5, w8  =  2.806, -2.758, 17.966
# w3, w6, w9  =  3.408, -4.678, 21.954
# epoch: 15
# y1, y2, y3 = 27.057, -29.582, 178.644
# E  = 0.1521959
# x1b, x2b,x3b  = -5.198, -7.385, -9.572
# w1b, x4b,x7b  =  0.114,  0.836, -0.712
# w2b, x5b,x8b  =  0.171,  1.253, -1.067
# w3b, x6b,x9b  =  0.228,  1.671, -1.423
# b1b, b2b,b3b  =  0.057,  0.418, -0.712
# w1, w4, w7  =  2.203, -0.847, 13.984
# w2, w5, w8  =  2.804, -2.771, 17.976
# w3, w6, w9  =  3.405, -4.694, 21.968
# epoch: 16
# y1, y2, y3 = 27.040, -29.708, 178.754
# E  = 0.0736961
# x1b, x2b,x3b  = -3.593, -5.112, -6.630
# w1b, x4b,x7b  =  0.080,  0.585, -0.491
# w2b, x5b,x8b  =  0.120,  0.877, -0.737
# w3b, x6b,x9b  =  0.160,  1.170, -0.982
# b1b, b2b,b3b  =  0.040,  0.292, -0.491
# w1, w4, w7  =  2.202, -0.853, 13.989
# w2, w5, w8  =  2.803, -2.780, 17.984
# w3, w6, w9  =  3.404, -4.706, 21.978
# epoch: 17
# y1, y2, y3 = 27.028, -29.795, 178.831
# E  = 0.0356922
# x1b, x2b,x3b  = -2.483, -3.537, -4.592
# w1b, x4b,x7b  =  0.056,  0.409, -0.339
# w2b, x5b,x8b  =  0.084,  0.614, -0.508
# w3b, x6b,x9b  =  0.112,  0.819, -0.678
# b1b, b2b,b3b  =  0.028,  0.205, -0.339
# w1, w4, w7  =  2.201, -0.857, 13.992
# w2, w5, w8  =  2.802, -2.786, 17.989
# w3, w6, w9  =  3.403, -4.714, 21.985
# epoch: 18
# y1, y2, y3 = 27.020, -29.857, 178.883
# E  = 0.0172897
# x1b, x2b,x3b  = -1.715, -2.447, -3.179
# w1b, x4b,x7b  =  0.039,  0.287, -0.234
# w2b, x5b,x8b  =  0.059,  0.430, -0.351
# w3b, x6b,x9b  =  0.078,  0.573, -0.468
# b1b, b2b,b3b  =  0.020,  0.143, -0.234
# w1, w4, w7  =  2.201, -0.860, 13.995
# w2, w5, w8  =  2.801, -2.790, 17.992
# w3, w6, w9  =  3.402, -4.720, 21.990
# epoch: 19
# y1, y2, y3 = 27.014, -29.900, 178.919
# E  = 0.0083770
# x1b, x2b,x3b  = -1.185, -1.693, -2.200
# w1b, x4b,x7b  =  0.027,  0.201, -0.161
# w2b, x5b,x8b  =  0.041,  0.301, -0.242
# w3b, x6b,x9b  =  0.055,  0.401, -0.323
# b1b, b2b,b3b  =  0.014,  0.100, -0.161
# w1, w4, w7  =  2.201, -0.862, 13.996
# w2, w5, w8  =  2.801, -2.793, 17.995
# w3, w6, w9  =  3.401, -4.724, 21.993
# epoch: 20
# y1, y2, y3 = 27.010, -29.930, 178.944
# E  = 0.0040595
# x1b, x2b,x3b  = -0.818, -1.171, -1.523
# w1b, x4b,x7b  =  0.019,  0.140, -0.111
# w2b, x5b,x8b  =  0.029,  0.211, -0.167
# w3b, x6b,x9b  =  0.038,  0.281, -0.223
# b1b, b2b,b3b  =  0.010,  0.070, -0.111
# w1, w4, w7  =  2.200, -0.863, 13.998
# w2, w5, w8  =  2.801, -2.795, 17.996
# w3, w6, w9  =  3.401, -4.727, 21.995
# epoch: 21
# y1, y2, y3 = 27.007, -29.951, 178.962
# E  = 0.0019676
# x1b, x2b,x3b  = -0.565, -0.810, -1.054
# w1b, x4b,x7b  =  0.013,  0.098, -0.077
# w2b, x5b,x8b  =  0.020,  0.147, -0.115
# w3b, x6b,x9b  =  0.027,  0.197, -0.154
# b1b, b2b,b3b  =  0.007,  0.049, -0.077
# w1, w4, w7  =  2.200, -0.864, 13.998
# w2, w5, w8  =  2.800, -2.797, 17.997
# w3, w6, w9  =  3.401, -4.729, 21.997
# epoch: 22
# y1, y2, y3 = 27.005, -29.966, 178.974
# E  = 0.0009539
# x1b, x2b,x3b  = -0.390, -0.560, -0.730
# w1b, x4b,x7b  =  0.009,  0.069, -0.053
# w2b, x5b,x8b  =  0.014,  0.103, -0.079
# w3b, x6b,x9b  =  0.019,  0.138, -0.106
# b1b, b2b,b3b  =  0.005,  0.034, -0.053
# w1, w4, w7  =  2.200, -0.865, 13.999
# w2, w5, w8  =  2.800, -2.798, 17.998
# w3, w6, w9  =  3.400, -4.730, 21.998
# epoch: 23
# y1, y2, y3 = 27.003, -29.976, 178.982
# E  = 0.0004625
# x1b, x2b,x3b  = -0.270, -0.387, -0.505
# w1b, x4b,x7b  =  0.007,  0.048, -0.037
# w2b, x5b,x8b  =  0.010,  0.072, -0.055
# w3b, x6b,x9b  =  0.013,  0.096, -0.073
# b1b, b2b,b3b  =  0.003,  0.024, -0.037
# w1, w4, w7  =  2.200, -0.866, 13.999
# w2, w5, w8  =  2.800, -2.798, 17.999
# w3, w6, w9  =  3.400, -4.731, 21.998
# epoch: 24
# y1, y2, y3 = 27.002, -29.983, 178.987
# E  = 0.0002243
# x1b, x2b,x3b  = -0.186, -0.268, -0.349
# w1b, x4b,x7b  =  0.005,  0.034, -0.025
# w2b, x5b,x8b  =  0.007,  0.051, -0.038
# w3b, x6b,x9b  =  0.009,  0.067, -0.050
# b1b, b2b,b3b  =  0.002,  0.017, -0.025
# w1, w4, w7  =  2.200, -0.866, 13.999
# w2, w5, w8  =  2.800, -2.799, 17.999
# w3, w6, w9  =  3.400, -4.732, 21.999
# epoch: 25
# y1, y2, y3 = 27.002, -29.988, 178.991
# E  = 0.0001088
# x1b, x2b,x3b  = -0.129, -0.185, -0.242
# w1b, x4b,x7b  =  0.003,  0.024, -0.017
# w2b, x5b,x8b  =  0.005,  0.035, -0.026
# w3b, x6b,x9b  =  0.006,  0.047, -0.035
# b1b, b2b,b3b  =  0.002,  0.012, -0.017
# w1, w4, w7  =  2.200, -0.866, 14.000
# w2, w5, w8  =  2.800, -2.799, 17.999
# w3, w6, w9  =  3.400, -4.732, 21.999
# epoch: 26
# y1, y2, y3 = 27.001, -29.992, 178.994
# E  = 0.0000528
# x1b, x2b,x3b  = -0.089, -0.128, -0.167
# w1b, x4b,x7b  =  0.002,  0.017, -0.012
# w2b, x5b,x8b  =  0.003,  0.025, -0.018
# w3b, x6b,x9b  =  0.005,  0.033, -0.024
# b1b, b2b,b3b  =  0.001,  0.008, -0.012
# w1, w4, w7  =  2.200, -0.866, 14.000
# w2, w5, w8  =  2.800, -2.799, 18.000
# w3, w6, w9  =  3.400, -4.733, 21.999
# epoch: 27
# y1, y2, y3 = 27.001, -29.994, 178.996
# E  = 0.0000256
# x1b, x2b,x3b  = -0.061, -0.089, -0.116
# w1b, x4b,x7b  =  0.002,  0.012, -0.008
# w2b, x5b,x8b  =  0.002,  0.017, -0.012
# w3b, x6b,x9b  =  0.003,  0.023, -0.017
# b1b, b2b,b3b  =  0.001,  0.006, -0.008
# w1, w4, w7  =  2.200, -0.866, 14.000
# w2, w5, w8  =  2.800, -2.800, 18.000
# w3, w6, w9  =  3.400, -4.733, 22.000
# epoch: 28
# y1, y2, y3 = 27.001, -29.996, 178.997
# E  = 0.0000124
# x1b, x2b,x3b  = -0.042, -0.061, -0.080
# w1b, x4b,x7b  =  0.001,  0.008, -0.006
# w2b, x5b,x8b  =  0.002,  0.012, -0.009
# w3b, x6b,x9b  =  0.002,  0.016, -0.011
# b1b, b2b,b3b  =  0.001,  0.004, -0.006
# w1, w4, w7  =  2.200, -0.866, 14.000
# w2, w5, w8  =  2.800, -2.800, 18.000
# w3, w6, w9  =  3.400, -4.733, 22.000
# epoch: 29
# y1, y2, y3 = 27.000, -29.997, 178.998
# E  = 0.0000060
# x1b, x2b,x3b  = -0.029, -0.042, -0.056
# w1b, x4b,x7b  =  0.001,  0.006, -0.004
# w2b, x5b,x8b  =  0.001,  0.009, -0.006
# w3b, x6b,x9b  =  0.002,  0.011, -0.008
# b1b, b2b,b3b  =  0.000,  0.003, -0.004
# w1, w4, w7  =  2.200, -0.867, 14.000
# w2, w5, w8  =  2.800, -2.800, 18.000
# w3, w6, w9  =  3.400, -4.733, 22.000
# epoch: 30
# y1, y2, y3 = 27.000, -29.998, 178.999
# E  = 0.0000029
# x1b, x2b,x3b  = -0.020, -0.029, -0.038
# w1b, x4b,x7b  =  0.001,  0.004, -0.003
# w2b, x5b,x8b  =  0.001,  0.006, -0.004
# w3b, x6b,x9b  =  0.001,  0.008, -0.005
# b1b, b2b,b3b  =  0.000,  0.002, -0.003
# w1, w4, w7  =  2.200, -0.867, 14.000
# w2, w5, w8  =  2.800, -2.800, 18.000
# w3, w6, w9  =  3.400, -4.733, 22.000
# epoch: 31
# y1, y2, y3 = 27.000, -29.999, 178.999
# E  = 0.0000014
# x1b, x2b,x3b  = -0.014, -0.020, -0.027
# w1b, x4b,x7b  =  0.000,  0.003, -0.002
# w2b, x5b,x8b  =  0.001,  0.004, -0.003
# w3b, x6b,x9b  =  0.001,  0.006, -0.004
# b1b, b2b,b3b  =  0.000,  0.001, -0.002
# w1, w4, w7  =  2.200, -0.867, 14.000
# w2, w5, w8  =  2.800, -2.800, 18.000
# w3, w6, w9  =  3.400, -4.733, 22.000
# epoch: 32
# y1, y2, y3 = 27.000, -29.999, 178.999
# E  = 0.0000007
# x1b, x2b,x3b  = -0.010, -0.014, -0.018
# w1b, x4b,x7b  =  0.000,  0.002, -0.001
# w2b, x5b,x8b  =  0.000,  0.003, -0.002
# w3b, x6b,x9b  =  0.001,  0.004, -0.003
# b1b, b2b,b3b  =  0.000,  0.001, -0.001
# w1, w4, w7  =  2.200, -0.867, 14.000
# w2, w5, w8  =  2.800, -2.800, 18.000
# w3, w6, w9  =  3.400, -4.733, 22.000
# epoch: 33
# y1, y2, y3 = 27.000, -29.999, 179.000
# E  = 0.0000003
# x1b, x2b,x3b  = -0.007, -0.010, -0.013
# w1b, x4b,x7b  =  0.000,  0.001, -0.001
# w2b, x5b,x8b  =  0.000,  0.002, -0.001
# w3b, x6b,x9b  =  0.000,  0.003, -0.002
# b1b, b2b,b3b  =  0.000,  0.001, -0.001
# w1, w4, w7  =  2.200, -0.867, 14.000
# w2, w5, w8  =  2.800, -2.800, 18.000
# w3, w6, w9  =  3.400, -4.733, 22.000
# epoch: 34
# y1, y2, y3 = 27.000, -30.000, 179.000
# E  = 0.0000002
# x1b, x2b,x3b  = -0.005, -0.007, -0.009
# w1b, x4b,x7b  =  0.000,  0.001, -0.001
# w2b, x5b,x8b  =  0.000,  0.001, -0.001
# w3b, x6b,x9b  =  0.000,  0.002, -0.001
# b1b, b2b,b3b  =  0.000,  0.000, -0.001
# w1, w4, w7  =  2.200, -0.867, 14.000
# w2, w5, w8  =  2.800, -2.800, 18.000
# w3, w6, w9  =  3.400, -4.733, 22.000
# epoch: 35
# y1, y2, y3 = 27.000, -30.000, 179.000
# E  = 0.0000001
